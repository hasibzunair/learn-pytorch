# %% [markdown]
# # VGG16 Convolutional Neural Network for Kaggle's Cats and Dogs Images
#
# Adapted from https://github.com/rasbt/deeplearning-models

# %% [markdown]
# ## Imports

# %%
import time
import os

import numpy as np

import torch
import torch.nn.functional as F
import torch.nn as nn


from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torchvision import transforms

from PIL import Image
import matplotlib.pyplot as plt


if torch.cuda.is_available():
    torch.backends.cudnn.deterministic = True

# %%
# %matplotlib inline

# %% [markdown]
# ## Settings

# %%
##########################
### SETTINGS
##########################

# Device
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(DEVICE)

# Hyperparameters
RANDOM_SEED = 1
LEARNING_RATE = 0.001
NUM_EPOCHS = 100
BATCH_SIZE = 128

# Architecture
NUM_CLASSES = 2
# Out:
# cuda:0

# %% [markdown]
# ## Cats vs Dogs Dataset

# %% [markdown]
# Download the Kaggle Cats and Dogs Dataset from  https://www.kaggle.com/c/dogs-vs-cats/data by clicking on the "Download All" link

# %% [markdown]
# Then, unzip the dataset.

# %% [markdown]
# The dataset folder consists of two subfolders, `train`, and `test1`, which contain the training and test images in jpg format, respectively. Note that the test set examples are unlabeled.

# %%
import os

DATASET_DIR = '../../datasets/dogs-vs-cats'
num_train_cats = len([i for i in os.listdir(os.path.join(DATASET_DIR, 'train')) 
                      if i.endswith('.jpg') and i.startswith('cat')])

num_train_dogs = len([i for i in os.listdir(os.path.join(DATASET_DIR, 'train')) 
                      if i.endswith('.jpg') and i.startswith('dog')])

print(f'Training set cats: {num_train_cats}')
print(f'Training set dogs: {num_train_dogs}')
# Out:
# Training set cats: 12500
# Training set dogs: 12500

# %% [markdown]
# The naming scheme within each of these subfolders is `<class>.<imagenumber>.jpg` like `cat.0.jpg`.

# %%
img = Image.open(os.path.join(DATASET_DIR, 'train', 'cat.59.jpg'))
print(np.asarray(img, dtype=np.uint8).shape)
plt.imshow(img);
# Out:
# (331, 464, 3)

# %% [markdown]
# ### Creating Validation and Test Subsets

# %% [markdown]
# - Move 2500 images from the training folder into a test set folder
# - Move 2500 images from the training folder into a validation set folder

# %%
if not os.path.exists(os.path.join(DATASET_DIR, 'test')):
    os.mkdir(os.path.join(DATASET_DIR, 'test'))

if not os.path.exists(os.path.join(DATASET_DIR, 'valid')):
    os.mkdir(os.path.join(DATASET_DIR, 'valid'))

# %%
for fname in os.listdir(os.path.join(DATASET_DIR, 'train')):
    if not fname.endswith('.jpg'):
        continue
    _, img_num, _ = fname.split('.')
    filepath = os.path.join(DATASET_DIR, 'train', fname)
    img_num = int(img_num)
    if img_num > 11249:
        os.rename(filepath, filepath.replace('train', 'test'))
    elif img_num > 9999:
        os.rename(filepath, filepath.replace('train', 'valid'))

# %% [markdown]
# ### Standardizing Images

# %% [markdown]
# Getting mean and standard devation for normalizing images via z-score normalization. For details, see the related notebook [./cnn-standardized.ipynb](https://github.com/rasbt/deeplearning-models/blob/master/pytorch_ipynb/cnn/cnn-standardized.ipynb).

# %%
class CatsDogsDataset(Dataset):
    """Custom Dataset for loading CelebA face images"""

    def __init__(self, img_dir, transform=None):
    
        self.img_dir = img_dir
        
        self.img_names = [i for i in 
                          os.listdir(img_dir) 
                          if i.endswith('.jpg')]
        
        self.y = []
        for i in self.img_names:
            if i.split('.')[0] == 'cat':
                self.y.append(0)
            else:
                self.y.append(1)
        
        self.transform = transform

    def __getitem__(self, index):
        img = Image.open(os.path.join(self.img_dir,
                                      self.img_names[index]))
        
        if self.transform is not None:
            img = self.transform(img)
        
        label = self.y[index]
        return img, label

    def __len__(self):
        return len(self.y)

    

custom_transform1 = transforms.Compose([transforms.Resize([64, 64]),
                                        transforms.ToTensor()])

train_dataset = CatsDogsDataset(img_dir=os.path.join(DATASET_DIR, 'train'), 
                                transform=custom_transform1)

train_loader = DataLoader(dataset=train_dataset, 
                          batch_size=5000, 
                          shuffle=False)

train_mean = []
train_std = []

for i, image in enumerate(train_loader, 0):
    numpy_image = image[0].numpy()
    
    batch_mean = np.mean(numpy_image, axis=(0, 2, 3))
    batch_std = np.std(numpy_image, axis=(0, 2, 3))
    
    train_mean.append(batch_mean)
    train_std.append(batch_std)

train_mean = torch.tensor(np.mean(train_mean, axis=0))
train_std = torch.tensor(np.mean(train_std, axis=0))

print('Mean:', train_mean)
print('Std Dev:', train_std)
# Out:
# Mean: tensor([0.4875, 0.4544, 0.4164])
# Std Dev: tensor([0.2521, 0.2453, 0.2481])

# %% [markdown]
# ### Dataloaders

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomRotation(5),
        transforms.RandomHorizontalFlip(),
        transforms.RandomResizedCrop(64, scale=(0.96, 1.0), ratio=(0.95, 1.05)),
        transforms.ToTensor(),
        transforms.Normalize(train_mean, train_std)
    ]),
    'valid': transforms.Compose([
        transforms.Resize([64, 64]),
        transforms.ToTensor(),
        transforms.Normalize(train_mean, train_std)
    ]),
}


train_dataset = CatsDogsDataset(img_dir=os.path.join(DATASET_DIR, 'train'), 
                                transform=data_transforms['train'])

train_loader = DataLoader(dataset=train_dataset, 
                          batch_size=BATCH_SIZE,
                          drop_last=True,
                          shuffle=True)

valid_dataset = CatsDogsDataset(img_dir=os.path.join(DATASET_DIR, 'valid'), 
                                transform=data_transforms['valid'])

valid_loader = DataLoader(dataset=valid_dataset, 
                          batch_size=BATCH_SIZE, 
                          shuffle=False)

test_dataset = CatsDogsDataset(img_dir=os.path.join(DATASET_DIR, 'test'), 
                               transform=data_transforms['valid'])

test_loader = DataLoader(dataset=test_dataset, 
                         batch_size=BATCH_SIZE, 
                         shuffle=False)

# %% [markdown]
# ## Model

# %%
##########################
### MODEL
##########################


class VGG16(torch.nn.Module):

    def __init__(self, num_classes):
        super(VGG16, self).__init__()
        
        # calculate same padding:
        # (w - k + 2*p)/s + 1 = o
        # => p = (s(o-1) - w + k)/2
        
        self.block_1 = nn.Sequential(
                nn.Conv2d(in_channels=3,
                          out_channels=64,
                          kernel_size=(3, 3),
                          stride=(1, 1),
                          # (1(32-1)- 32 + 3)/2 = 1
                          padding=1), 
                nn.ReLU(),
                nn.Conv2d(in_channels=64,
                          out_channels=64,
                          kernel_size=(3, 3),
                          stride=(1, 1),
                          padding=1),
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=(2, 2),
                             stride=(2, 2))
        )
        
        self.block_2 = nn.Sequential(
                nn.Conv2d(in_channels=64,
                          out_channels=128,
                          kernel_size=(3, 3),
                          stride=(1, 1),
                          padding=1),
                nn.ReLU(),
                nn.Conv2d(in_channels=128,
                          out_channels=128,
                          kernel_size=(3, 3),
                          stride=(1, 1),
                          padding=1),
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=(2, 2),
                             stride=(2, 2))
        )
        
        self.block_3 = nn.Sequential(        
                nn.Conv2d(in_channels=128,
                          out_channels=256,
                          kernel_size=(3, 3),
                          stride=(1, 1),
                          padding=1),
                nn.ReLU(),
                nn.Conv2d(in_channels=256,
                          out_channels=256,
                          kernel_size=(3, 3),
                          stride=(1, 1),
                          padding=1),
                nn.ReLU(),        
                nn.Conv2d(in_channels=256,
                          out_channels=256,
                          kernel_size=(3, 3),
                          stride=(1, 1),
                          padding=1),
                nn.ReLU(),
                nn.Conv2d(in_channels=256,
                          out_channels=256,
                          kernel_size=(3, 3),
                          stride=(1, 1),
                          padding=1),
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=(2, 2),
                             stride=(2, 2))
        )
        
          
        self.block_4 = nn.Sequential(   
                nn.Conv2d(in_channels=256,
                          out_channels=512,
                          kernel_size=(3, 3),
                          stride=(1, 1),
                          padding=1),
                nn.ReLU(),        
                nn.Conv2d(in_channels=512,
                          out_channels=512,
                          kernel_size=(3, 3),
                          stride=(1, 1),
                          padding=1),
                nn.ReLU(),        
                nn.Conv2d(in_channels=512,
                          out_channels=512,
                          kernel_size=(3, 3),
                          stride=(1, 1),
                          padding=1),
                nn.ReLU(),
                nn.Conv2d(in_channels=512,
                          out_channels=512,
                          kernel_size=(3, 3),
                          stride=(1, 1),
                          padding=1),
                nn.ReLU(),   
                nn.MaxPool2d(kernel_size=(2, 2),
                             stride=(2, 2))
        )
        
        self.block_5 = nn.Sequential(
                nn.Conv2d(in_channels=512,
                          out_channels=512,
                          kernel_size=(3, 3),
                          stride=(1, 1),
                          padding=1),
                nn.ReLU(),            
                nn.Conv2d(in_channels=512,
                          out_channels=512,
                          kernel_size=(3, 3),
                          stride=(1, 1),
                          padding=1),
                nn.ReLU(),            
                nn.Conv2d(in_channels=512,
                          out_channels=512,
                          kernel_size=(3, 3),
                          stride=(1, 1),
                          padding=1),
                nn.ReLU(),
                nn.Conv2d(in_channels=512,
                          out_channels=512,
                          kernel_size=(3, 3),
                          stride=(1, 1),
                          padding=1),
                nn.ReLU(),   
                nn.MaxPool2d(kernel_size=(2, 2),
                             stride=(2, 2))             
        )
        
        self.classifier = nn.Sequential(
                nn.Linear(512*2*2, 4096),
                nn.ReLU(),   
                nn.Linear(4096, 4096),
                nn.ReLU(),
                nn.Linear(4096, num_classes)
        )
            
        
        for m in self.modules():
            if isinstance(m, torch.nn.Conv2d):
                #n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                #m.weight.data.normal_(0, np.sqrt(2. / n))
                m.weight.detach().normal_(0, 0.05)
                if m.bias is not None:
                    m.bias.detach().zero_()
            elif isinstance(m, torch.nn.Linear):
                m.weight.detach().normal_(0, 0.05)
                m.bias.detach().detach().zero_()
        
        
    def forward(self, x):

        x = self.block_1(x)
        x = self.block_2(x)
        x = self.block_3(x)
        x = self.block_4(x)
        x = self.block_5(x)

        logits = self.classifier(x.view(-1, 512*2*2))
        probas = F.softmax(logits, dim=1)

        return logits, probas

# %%
torch.manual_seed(RANDOM_SEED)
model = VGG16(num_classes=NUM_CLASSES)

model = model.to(DEVICE)
print(model)

optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
# Out:
# VGG16(
#   (block_1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (block_2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (block_3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (block_4): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (block_5): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=2048, out_features=4096, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=4096, out_features=4096, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=4096, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# ## Training

# %%
def compute_accuracy_and_loss(model, data_loader, device):
    correct_pred, num_examples = 0, 0
    cross_entropy = 0.
    for i, (features, targets) in enumerate(data_loader):
            
        features = features.to(device)
        targets = targets.to(device)

        logits, probas = model(features)
        cross_entropy += F.cross_entropy(logits, targets).item()
        _, predicted_labels = torch.max(probas, 1)
        num_examples += targets.size(0)
        correct_pred += (predicted_labels == targets).sum()
    return correct_pred.float()/num_examples * 100, cross_entropy/num_examples
    

start_time = time.time()
train_acc_lst, valid_acc_lst = [], []
train_loss_lst, valid_loss_lst = [], []

for epoch in range(NUM_EPOCHS):
    
    model.train()
    
    for batch_idx, (features, targets) in enumerate(train_loader):
    
        ### PREPARE MINIBATCH
        features = features.to(DEVICE)
        targets = targets.to(DEVICE)
            
        ### FORWARD AND BACK PROP
        logits, probas = model(features)
        cost = F.cross_entropy(logits, targets)
        optimizer.zero_grad()
        
        cost.backward()
        
        ### UPDATE MODEL PARAMETERS
        optimizer.step()
        
        ### LOGGING
        if not batch_idx % 120:
            print (f'Epoch: {epoch+1:03d}/{NUM_EPOCHS:03d} | '
                   f'Batch {batch_idx:03d}/{len(train_loader):03d} |' 
                   f' Cost: {cost:.4f}')

    # no need to build the computation graph for backprop when computing accuracy
    model.eval()
    with torch.set_grad_enabled(False):
        train_acc, train_loss = compute_accuracy_and_loss(model, train_loader, device=DEVICE)
        valid_acc, valid_loss = compute_accuracy_and_loss(model, valid_loader, device=DEVICE)
        train_acc_lst.append(train_acc)
        valid_acc_lst.append(valid_acc)
        train_loss_lst.append(train_loss)
        valid_loss_lst.append(valid_loss)
        print(f'Epoch: {epoch+1:03d}/{NUM_EPOCHS:03d} Train Acc.: {train_acc:.2f}%'
              f' | Validation Acc.: {valid_acc:.2f}%')
        
    elapsed = (time.time() - start_time)/60
    print(f'Time elapsed: {elapsed:.2f} min')

elapsed = (time.time() - start_time)/60
print(f'Total Training Time: {elapsed:.2f} min') # 3 min per epoch
# Out:
# Epoch: 001/100 | Batch 000/156 | Cost: 1281.1154
# Epoch: 001/100 | Batch 120/156 | Cost: 0.7709
# Epoch: 001/100 Train Acc.: 58.43% | Validation Acc.: 56.72%
# Time elapsed: 1.87 min
# Epoch: 002/100 | Batch 000/156 | Cost: 0.6860
# Epoch: 002/100 | Batch 120/156 | Cost: 0.6510
# Epoch: 002/100 Train Acc.: 62.27% | Validation Acc.: 62.84%
# Time elapsed: 3.70 min
# Epoch: 003/100 | Batch 000/156 | Cost: 0.6833
# Epoch: 003/100 | Batch 120/156 | Cost: 0.6604
# Epoch: 003/100 Train Acc.: 63.03% | Validation Acc.: 62.28%
# Time elapsed: 5.51 min
# Epoch: 004/100 | Batch 000/156 | Cost: 0.6257
# Epoch: 004/100 | Batch 120/156 | Cost: 0.6778
# Epoch: 004/100 Train Acc.: 64.42% | Validation Acc.: 64.60%
# Time elapsed: 7.32 min
# Epoch: 005/100 | Batch 000/156 | Cost: 0.6305
# Epoch: 005/100 | Batch 120/156 | Cost: 0.6226
# Epoch: 005/100 Train Acc.: 64.16% | Validation Acc.: 63.92%
# Time elapsed: 9.13 min
# Epoch: 006/100 | Batch 000/156 | Cost: 0.6904
# Epoch: 006/100 | Batch 120/156 | Cost: 0.6379
# Epoch: 006/100 Train Acc.: 61.37% | Validation Acc.: 60.48%
# Time elapsed: 10.94 min
# Epoch: 007/100 | Batch 000/156 | Cost: 0.7077
# Epoch: 007/100 | Batch 120/156 | Cost: 0.5433
# Epoch: 007/100 Train Acc.: 63.90% | Validation Acc.: 62.28%
# Time elapsed: 12.74 min
# Epoch: 008/100 | Batch 000/156 | Cost: 0.5768
# Epoch: 008/100 | Batch 120/156 | Cost: 0.6193
# Epoch: 008/100 Train Acc.: 66.18% | Validation Acc.: 65.96%
# Time elapsed: 14.55 min
# Epoch: 009/100 | Batch 000/156 | Cost: 0.5812
# Epoch: 009/100 | Batch 120/156 | Cost: 0.6181
# Epoch: 009/100 Train Acc.: 67.49% | Validation Acc.: 67.16%
# Time elapsed: 16.36 min
# Epoch: 010/100 | Batch 000/156 | Cost: 0.5128
# Epoch: 010/100 | Batch 120/156 | Cost: 0.6178
# Epoch: 010/100 Train Acc.: 68.63% | Validation Acc.: 67.84%
# Time elapsed: 18.16 min
# Epoch: 011/100 | Batch 000/156 | Cost: 0.6018
# Epoch: 011/100 | Batch 120/156 | Cost: 0.5948
# Epoch: 011/100 Train Acc.: 69.34% | Validation Acc.: 69.04%
# Time elapsed: 19.97 min
# Epoch: 012/100 | Batch 000/156 | Cost: 0.5699
# Epoch: 012/100 | Batch 120/156 | Cost: 0.6134
# Epoch: 012/100 Train Acc.: 69.51% | Validation Acc.: 67.24%
# Time elapsed: 21.77 min
# Epoch: 013/100 | Batch 000/156 | Cost: 0.5756
# Epoch: 013/100 | Batch 120/156 | Cost: 0.5605
# Epoch: 013/100 Train Acc.: 64.86% | Validation Acc.: 65.52%
# Time elapsed: 23.58 min
# Epoch: 014/100 | Batch 000/156 | Cost: 0.6610
# Epoch: 014/100 | Batch 120/156 | Cost: 0.6026
# Epoch: 014/100 Train Acc.: 66.12% | Validation Acc.: 66.24%
# Time elapsed: 25.39 min
# Epoch: 015/100 | Batch 000/156 | Cost: 0.5683
# Epoch: 015/100 | Batch 120/156 | Cost: 0.5818
# Epoch: 015/100 Train Acc.: 72.00% | Validation Acc.: 72.16%
# Time elapsed: 27.19 min
# Epoch: 016/100 | Batch 000/156 | Cost: 0.5757
# Epoch: 016/100 | Batch 120/156 | Cost: 0.5906
# Epoch: 016/100 Train Acc.: 71.64% | Validation Acc.: 71.64%
# Time elapsed: 29.00 min
# Epoch: 017/100 | Batch 000/156 | Cost: 0.5551
# Epoch: 017/100 | Batch 120/156 | Cost: 0.5197
# Epoch: 017/100 Train Acc.: 73.22% | Validation Acc.: 72.92%
# Time elapsed: 30.80 min
# Epoch: 018/100 | Batch 000/156 | Cost: 0.5490
# Epoch: 018/100 | Batch 120/156 | Cost: 0.5986
# Epoch: 018/100 Train Acc.: 72.99% | Validation Acc.: 72.64%
# Time elapsed: 32.61 min
# Epoch: 019/100 | Batch 000/156 | Cost: 0.5288
# Epoch: 019/100 | Batch 120/156 | Cost: 0.5241
# Epoch: 019/100 Train Acc.: 74.72% | Validation Acc.: 74.56%
# Time elapsed: 34.41 min
# Epoch: 020/100 | Batch 000/156 | Cost: 0.5786
# Epoch: 020/100 | Batch 120/156 | Cost: 0.4818
# Epoch: 020/100 Train Acc.: 74.09% | Validation Acc.: 74.04%
# Time elapsed: 36.22 min
# Epoch: 021/100 | Batch 000/156 | Cost: 0.5569
# Epoch: 021/100 | Batch 120/156 | Cost: 0.4277
# Epoch: 021/100 Train Acc.: 74.87% | Validation Acc.: 75.00%
# Time elapsed: 38.03 min
# Epoch: 022/100 | Batch 000/156 | Cost: 0.4731
# Epoch: 022/100 | Batch 120/156 | Cost: 0.4463
# Epoch: 022/100 Train Acc.: 73.71% | Validation Acc.: 73.00%
# Time elapsed: 39.83 min
# Epoch: 023/100 | Batch 000/156 | Cost: 0.5143
# Epoch: 023/100 | Batch 120/156 | Cost: 0.5006
# Epoch: 023/100 Train Acc.: 76.10% | Validation Acc.: 76.12%
# Time elapsed: 41.64 min
# Epoch: 024/100 | Batch 000/156 | Cost: 0.4073
# Epoch: 024/100 | Batch 120/156 | Cost: 0.4703
# Epoch: 024/100 Train Acc.: 76.07% | Validation Acc.: 75.44%
# Time elapsed: 43.44 min
# Epoch: 025/100 | Batch 000/156 | Cost: 0.4340
# Epoch: 025/100 | Batch 120/156 | Cost: 0.4900
# Epoch: 025/100 Train Acc.: 74.42% | Validation Acc.: 75.08%
# Time elapsed: 45.25 min
# Epoch: 026/100 | Batch 000/156 | Cost: 0.5007
# Epoch: 026/100 | Batch 120/156 | Cost: 0.4179
# Epoch: 026/100 Train Acc.: 77.08% | Validation Acc.: 76.92%
# Time elapsed: 47.05 min
# Epoch: 027/100 | Batch 000/156 | Cost: 0.5149
# Epoch: 027/100 | Batch 120/156 | Cost: 0.4534
# Epoch: 027/100 Train Acc.: 77.20% | Validation Acc.: 77.20%
# Time elapsed: 48.86 min
# Epoch: 028/100 | Batch 000/156 | Cost: 0.4573
# Epoch: 028/100 | Batch 120/156 | Cost: 0.4921
# Epoch: 028/100 Train Acc.: 77.71% | Validation Acc.: 76.56%
# Time elapsed: 50.66 min
# Epoch: 029/100 | Batch 000/156 | Cost: 0.5510
# Epoch: 029/100 | Batch 120/156 | Cost: 0.4662
# Epoch: 029/100 Train Acc.: 79.58% | Validation Acc.: 78.32%
# Time elapsed: 52.47 min
# Epoch: 030/100 | Batch 000/156 | Cost: 0.4841
# Epoch: 030/100 | Batch 120/156 | Cost: 0.3683
# Epoch: 030/100 Train Acc.: 77.43% | Validation Acc.: 76.32%
# Time elapsed: 54.28 min
# Epoch: 031/100 | Batch 000/156 | Cost: 0.3960
# Epoch: 031/100 | Batch 120/156 | Cost: 0.3764
# Epoch: 031/100 Train Acc.: 76.29% | Validation Acc.: 73.92%
# Time elapsed: 56.08 min
# Epoch: 032/100 | Batch 000/156 | Cost: 0.4856
# Epoch: 032/100 | Batch 120/156 | Cost: 0.4640
# Epoch: 032/100 Train Acc.: 80.79% | Validation Acc.: 79.68%
# Time elapsed: 57.89 min
# Epoch: 033/100 | Batch 000/156 | Cost: 0.5142
# Epoch: 033/100 | Batch 120/156 | Cost: 0.4550
# Epoch: 033/100 Train Acc.: 77.19% | Validation Acc.: 76.00%
# Time elapsed: 59.73 min
# Epoch: 034/100 | Batch 000/156 | Cost: 0.4299
# Epoch: 034/100 | Batch 120/156 | Cost: 0.3861
# Epoch: 034/100 Train Acc.: 77.11% | Validation Acc.: 74.20%
# Time elapsed: 61.56 min
# Epoch: 035/100 | Batch 000/156 | Cost: 0.4726
# Epoch: 035/100 | Batch 120/156 | Cost: 0.4339
# Epoch: 035/100 Train Acc.: 82.00% | Validation Acc.: 80.64%
# Time elapsed: 63.40 min
# Epoch: 036/100 | Batch 000/156 | Cost: 0.4222
# Epoch: 036/100 | Batch 120/156 | Cost: 0.4027
# Epoch: 036/100 Train Acc.: 81.57% | Validation Acc.: 79.92%
# Time elapsed: 65.24 min
# Epoch: 037/100 | Batch 000/156 | Cost: 0.4566
# Epoch: 037/100 | Batch 120/156 | Cost: 0.3817
# Epoch: 037/100 Train Acc.: 83.16% | Validation Acc.: 81.40%
# Time elapsed: 67.08 min
# Epoch: 038/100 | Batch 000/156 | Cost: 0.3549
# Epoch: 038/100 | Batch 120/156 | Cost: 0.3585
# Epoch: 038/100 Train Acc.: 82.77% | Validation Acc.: 81.00%
# Time elapsed: 68.92 min
# Epoch: 039/100 | Batch 000/156 | Cost: 0.2457
# Epoch: 039/100 | Batch 120/156 | Cost: 0.3474
# Epoch: 039/100 Train Acc.: 83.14% | Validation Acc.: 80.76%
# Time elapsed: 70.75 min
# Epoch: 040/100 | Batch 000/156 | Cost: 0.3523
# Epoch: 040/100 | Batch 120/156 | Cost: 0.3773
# Epoch: 040/100 Train Acc.: 83.55% | Validation Acc.: 81.96%
# Time elapsed: 72.59 min
# Epoch: 041/100 | Batch 000/156 | Cost: 0.4176
# Epoch: 041/100 | Batch 120/156 | Cost: 0.3007
# Epoch: 041/100 Train Acc.: 84.67% | Validation Acc.: 81.72%
# Time elapsed: 74.43 min
# Epoch: 042/100 | Batch 000/156 | Cost: 0.2919
# Epoch: 042/100 | Batch 120/156 | Cost: 0.2788
# Epoch: 042/100 Train Acc.: 84.51% | Validation Acc.: 83.04%
# Time elapsed: 76.27 min
# Epoch: 043/100 | Batch 000/156 | Cost: 0.4239
# Epoch: 043/100 | Batch 120/156 | Cost: 0.3847
# Epoch: 043/100 Train Acc.: 84.88% | Validation Acc.: 82.20%
# Time elapsed: 78.11 min
# Epoch: 044/100 | Batch 000/156 | Cost: 0.2981
# Epoch: 044/100 | Batch 120/156 | Cost: 0.3889
# Epoch: 044/100 Train Acc.: 86.86% | Validation Acc.: 83.52%
# Time elapsed: 79.95 min
# Epoch: 045/100 | Batch 000/156 | Cost: 0.2983
# Epoch: 045/100 | Batch 120/156 | Cost: 0.2962
# Epoch: 045/100 Train Acc.: 86.37% | Validation Acc.: 83.48%
# Time elapsed: 81.79 min
# Epoch: 046/100 | Batch 000/156 | Cost: 0.3878
# Epoch: 046/100 | Batch 120/156 | Cost: 0.4540
# Epoch: 046/100 Train Acc.: 85.92% | Validation Acc.: 82.04%
# Time elapsed: 83.63 min
# Epoch: 047/100 | Batch 000/156 | Cost: 0.3257
# Epoch: 047/100 | Batch 120/156 | Cost: 0.2329
# Epoch: 047/100 Train Acc.: 87.61% | Validation Acc.: 84.12%
# Time elapsed: 85.47 min
# Epoch: 048/100 | Batch 000/156 | Cost: 0.2230
# Epoch: 048/100 | Batch 120/156 | Cost: 0.2687
# Epoch: 048/100 Train Acc.: 88.45% | Validation Acc.: 84.84%
# Time elapsed: 87.31 min
# Epoch: 049/100 | Batch 000/156 | Cost: 0.2074
# Epoch: 049/100 | Batch 120/156 | Cost: 0.2481
# Epoch: 049/100 Train Acc.: 84.51% | Validation Acc.: 80.40%
# Time elapsed: 89.14 min
# Epoch: 050/100 | Batch 000/156 | Cost: 0.4397
# Epoch: 050/100 | Batch 120/156 | Cost: 0.2373
# Epoch: 050/100 Train Acc.: 87.84% | Validation Acc.: 84.52%
# Time elapsed: 90.98 min
# Epoch: 051/100 | Batch 000/156 | Cost: 0.2182
# Epoch: 051/100 | Batch 120/156 | Cost: 0.2126
# Epoch: 051/100 Train Acc.: 87.87% | Validation Acc.: 85.08%
# Time elapsed: 92.81 min
# Epoch: 052/100 | Batch 000/156 | Cost: 0.2579
# Epoch: 052/100 | Batch 120/156 | Cost: 0.3048
# Epoch: 052/100 Train Acc.: 89.11% | Validation Acc.: 85.28%
# Time elapsed: 94.64 min
# Epoch: 053/100 | Batch 000/156 | Cost: 0.2652
# Epoch: 053/100 | Batch 120/156 | Cost: 0.2768
# Epoch: 053/100 Train Acc.: 89.36% | Validation Acc.: 85.00%
# Time elapsed: 96.46 min
# Epoch: 054/100 | Batch 000/156 | Cost: 0.2489
# Epoch: 054/100 | Batch 120/156 | Cost: 0.3503
# Epoch: 054/100 Train Acc.: 84.49% | Validation Acc.: 81.60%
# Time elapsed: 98.30 min
# Epoch: 055/100 | Batch 000/156 | Cost: 0.2688
# Epoch: 055/100 | Batch 120/156 | Cost: 0.1996
# Epoch: 055/100 Train Acc.: 87.76% | Validation Acc.: 84.68%
# Time elapsed: 100.13 min
# Epoch: 056/100 | Batch 000/156 | Cost: 0.2547
# Epoch: 056/100 | Batch 120/156 | Cost: 0.2328
# Epoch: 056/100 Train Acc.: 87.34% | Validation Acc.: 84.52%
# Time elapsed: 101.96 min
# Epoch: 057/100 | Batch 000/156 | Cost: 0.2544
# Epoch: 057/100 | Batch 120/156 | Cost: 0.2131
# Epoch: 057/100 Train Acc.: 90.07% | Validation Acc.: 85.48%
# Time elapsed: 103.80 min
# Epoch: 058/100 | Batch 000/156 | Cost: 0.2658
# Epoch: 058/100 | Batch 120/156 | Cost: 0.2216
# Epoch: 058/100 Train Acc.: 91.21% | Validation Acc.: 85.56%
# Time elapsed: 105.63 min
# Epoch: 059/100 | Batch 000/156 | Cost: 0.2426
# Epoch: 059/100 | Batch 120/156 | Cost: 0.2009
# Epoch: 059/100 Train Acc.: 90.83% | Validation Acc.: 85.72%
# Time elapsed: 107.46 min
# Epoch: 060/100 | Batch 000/156 | Cost: 0.2947
# Epoch: 060/100 | Batch 120/156 | Cost: 0.3041
# Epoch: 060/100 Train Acc.: 92.15% | Validation Acc.: 85.44%
# Time elapsed: 109.30 min
# Epoch: 061/100 | Batch 000/156 | Cost: 0.2744
# Epoch: 061/100 | Batch 120/156 | Cost: 0.1534
# Epoch: 061/100 Train Acc.: 91.07% | Validation Acc.: 85.32%
# Time elapsed: 111.13 min
# Epoch: 062/100 | Batch 000/156 | Cost: 0.2600
# Epoch: 062/100 | Batch 120/156 | Cost: 0.2871
# Epoch: 062/100 Train Acc.: 91.39% | Validation Acc.: 87.04%
# Time elapsed: 112.96 min
# Epoch: 063/100 | Batch 000/156 | Cost: 0.1834
# Epoch: 063/100 | Batch 120/156 | Cost: 0.2370
# Epoch: 063/100 Train Acc.: 86.84% | Validation Acc.: 80.12%
# Time elapsed: 114.79 min
# Epoch: 064/100 | Batch 000/156 | Cost: 0.2002
# Epoch: 064/100 | Batch 120/156 | Cost: 0.2169
# Epoch: 064/100 Train Acc.: 91.61% | Validation Acc.: 84.96%
# Time elapsed: 116.62 min
# Epoch: 065/100 | Batch 000/156 | Cost: 0.2046
# Epoch: 065/100 | Batch 120/156 | Cost: 0.2360
# Epoch: 065/100 Train Acc.: 92.79% | Validation Acc.: 86.16%
# Time elapsed: 118.45 min
# Epoch: 066/100 | Batch 000/156 | Cost: 0.1971
# Epoch: 066/100 | Batch 120/156 | Cost: 0.2836
# Epoch: 066/100 Train Acc.: 89.25% | Validation Acc.: 84.00%
# Time elapsed: 120.29 min
# Epoch: 067/100 | Batch 000/156 | Cost: 0.3175
# Epoch: 067/100 | Batch 120/156 | Cost: 0.2295
# Epoch: 067/100 Train Acc.: 91.67% | Validation Acc.: 85.40%
# Time elapsed: 122.12 min
# Epoch: 068/100 | Batch 000/156 | Cost: 0.1956
# Epoch: 068/100 | Batch 120/156 | Cost: 0.1565
# Epoch: 068/100 Train Acc.: 91.50% | Validation Acc.: 86.48%
# Time elapsed: 123.95 min
# Epoch: 069/100 | Batch 000/156 | Cost: 0.1565
# Epoch: 069/100 | Batch 120/156 | Cost: 0.1926
# Epoch: 069/100 Train Acc.: 93.95% | Validation Acc.: 85.76%
# Time elapsed: 125.78 min
# Epoch: 070/100 | Batch 000/156 | Cost: 0.1447
# Epoch: 070/100 | Batch 120/156 | Cost: 0.1381
# Epoch: 070/100 Train Acc.: 93.85% | Validation Acc.: 86.56%
# Time elapsed: 127.62 min
# Epoch: 071/100 | Batch 000/156 | Cost: 0.1725
# Epoch: 071/100 | Batch 120/156 | Cost: 0.1620
# Epoch: 071/100 Train Acc.: 93.65% | Validation Acc.: 86.20%
# Time elapsed: 129.44 min
# Epoch: 072/100 | Batch 000/156 | Cost: 0.1677
# Epoch: 072/100 | Batch 120/156 | Cost: 0.2963
# Epoch: 072/100 Train Acc.: 94.51% | Validation Acc.: 87.52%
# Time elapsed: 131.27 min
# Epoch: 073/100 | Batch 000/156 | Cost: 0.1774
# Epoch: 073/100 | Batch 120/156 | Cost: 0.2277
# Epoch: 073/100 Train Acc.: 92.35% | Validation Acc.: 86.08%
# Time elapsed: 133.09 min
# Epoch: 074/100 | Batch 000/156 | Cost: 0.1422
# Epoch: 074/100 | Batch 120/156 | Cost: 0.1553
# Epoch: 074/100 Train Acc.: 94.16% | Validation Acc.: 87.68%
# Time elapsed: 134.91 min
# Epoch: 075/100 | Batch 000/156 | Cost: 0.1230
# Epoch: 075/100 | Batch 120/156 | Cost: 0.1409
# Epoch: 075/100 Train Acc.: 93.78% | Validation Acc.: 86.40%
# Time elapsed: 136.74 min
# Epoch: 076/100 | Batch 000/156 | Cost: 0.1885
# Epoch: 076/100 | Batch 120/156 | Cost: 0.1237
# Epoch: 076/100 Train Acc.: 93.07% | Validation Acc.: 87.24%
# Time elapsed: 138.56 min
# Epoch: 077/100 | Batch 000/156 | Cost: 0.2121
# Epoch: 077/100 | Batch 120/156 | Cost: 0.1925
# Epoch: 077/100 Train Acc.: 94.36% | Validation Acc.: 86.40%
# Time elapsed: 140.39 min
# Epoch: 078/100 | Batch 000/156 | Cost: 0.1420
# Epoch: 078/100 | Batch 120/156 | Cost: 0.1646
# Epoch: 078/100 Train Acc.: 93.18% | Validation Acc.: 84.96%
# Time elapsed: 142.21 min
# Epoch: 079/100 | Batch 000/156 | Cost: 0.1659
# Epoch: 079/100 | Batch 120/156 | Cost: 0.1923
# Epoch: 079/100 Train Acc.: 93.51% | Validation Acc.: 86.24%
# Time elapsed: 144.03 min
# Epoch: 080/100 | Batch 000/156 | Cost: 0.1695
# Epoch: 080/100 | Batch 120/156 | Cost: 0.1072
# Epoch: 080/100 Train Acc.: 94.55% | Validation Acc.: 87.12%
# Time elapsed: 145.86 min
# Epoch: 081/100 | Batch 000/156 | Cost: 0.1182
# Epoch: 081/100 | Batch 120/156 | Cost: 0.1507
# Epoch: 081/100 Train Acc.: 95.65% | Validation Acc.: 87.88%
# Time elapsed: 147.68 min
# Epoch: 082/100 | Batch 000/156 | Cost: 0.1652
# Epoch: 082/100 | Batch 120/156 | Cost: 0.0907
# Epoch: 082/100 Train Acc.: 95.34% | Validation Acc.: 87.32%
# Time elapsed: 149.50 min
# Epoch: 083/100 | Batch 000/156 | Cost: 0.1058
# Epoch: 083/100 | Batch 120/156 | Cost: 0.1087
# Epoch: 083/100 Train Acc.: 94.29% | Validation Acc.: 85.44%
# Time elapsed: 151.33 min
# Epoch: 084/100 | Batch 000/156 | Cost: 0.1237
# Epoch: 084/100 | Batch 120/156 | Cost: 0.1813
# Epoch: 084/100 Train Acc.: 93.90% | Validation Acc.: 86.60%
# Time elapsed: 153.15 min
# Epoch: 085/100 | Batch 000/156 | Cost: 0.0907
# Epoch: 085/100 | Batch 120/156 | Cost: 0.1569
# Epoch: 085/100 Train Acc.: 95.92% | Validation Acc.: 88.60%
# Time elapsed: 154.98 min
# Epoch: 086/100 | Batch 000/156 | Cost: 0.0993
# Epoch: 086/100 | Batch 120/156 | Cost: 0.1449
# Epoch: 086/100 Train Acc.: 95.81% | Validation Acc.: 87.92%
# Time elapsed: 156.82 min
# Epoch: 087/100 | Batch 000/156 | Cost: 0.0818
# Epoch: 087/100 | Batch 120/156 | Cost: 0.2587
# Epoch: 087/100 Train Acc.: 93.82% | Validation Acc.: 85.36%
# Time elapsed: 158.65 min
# Epoch: 088/100 | Batch 000/156 | Cost: 0.0719
# Epoch: 088/100 | Batch 120/156 | Cost: 0.1062
# Epoch: 088/100 Train Acc.: 96.34% | Validation Acc.: 88.44%
# Time elapsed: 160.48 min
# Epoch: 089/100 | Batch 000/156 | Cost: 0.1336
# Epoch: 089/100 | Batch 120/156 | Cost: 0.1567
# Epoch: 089/100 Train Acc.: 96.13% | Validation Acc.: 86.76%
# Time elapsed: 162.32 min
# Epoch: 090/100 | Batch 000/156 | Cost: 0.1291
# Epoch: 090/100 | Batch 120/156 | Cost: 0.1247
# Epoch: 090/100 Train Acc.: 96.04% | Validation Acc.: 87.84%
# Time elapsed: 164.13 min
# Epoch: 091/100 | Batch 000/156 | Cost: 0.1647
# Epoch: 091/100 | Batch 120/156 | Cost: 0.2567
# Epoch: 091/100 Train Acc.: 96.12% | Validation Acc.: 87.68%
# Time elapsed: 165.93 min
# Epoch: 092/100 | Batch 000/156 | Cost: 0.1076
# Epoch: 092/100 | Batch 120/156 | Cost: 0.0716
# Epoch: 092/100 Train Acc.: 95.44% | Validation Acc.: 86.88%
# Time elapsed: 167.73 min
# Epoch: 093/100 | Batch 000/156 | Cost: 0.1052
# Epoch: 093/100 | Batch 120/156 | Cost: 0.1318
# Epoch: 093/100 Train Acc.: 96.10% | Validation Acc.: 88.36%
# Time elapsed: 169.53 min
# Epoch: 094/100 | Batch 000/156 | Cost: 0.1003
# Epoch: 094/100 | Batch 120/156 | Cost: 0.0818
# Epoch: 094/100 Train Acc.: 96.70% | Validation Acc.: 87.56%
# Time elapsed: 171.35 min
# Epoch: 095/100 | Batch 000/156 | Cost: 0.0558
# Epoch: 095/100 | Batch 120/156 | Cost: 0.1253
# Epoch: 095/100 Train Acc.: 95.55% | Validation Acc.: 86.76%
# Time elapsed: 173.16 min
# Epoch: 096/100 | Batch 000/156 | Cost: 0.1100
# Epoch: 096/100 | Batch 120/156 | Cost: 0.0605
# Epoch: 096/100 Train Acc.: 97.16% | Validation Acc.: 88.68%
# Time elapsed: 174.98 min
# Epoch: 097/100 | Batch 000/156 | Cost: 0.1042
# Epoch: 097/100 | Batch 120/156 | Cost: 0.2511
# Epoch: 097/100 Train Acc.: 95.13% | Validation Acc.: 86.68%
# Time elapsed: 176.79 min
# Epoch: 098/100 | Batch 000/156 | Cost: 0.1207
# Epoch: 098/100 | Batch 120/156 | Cost: 0.1702
# Epoch: 098/100 Train Acc.: 96.29% | Validation Acc.: 87.68%
# Time elapsed: 178.61 min
# Epoch: 099/100 | Batch 000/156 | Cost: 0.1172
# Epoch: 099/100 | Batch 120/156 | Cost: 0.1351
# Epoch: 099/100 Train Acc.: 97.15% | Validation Acc.: 87.96%
# Time elapsed: 180.42 min
# Epoch: 100/100 | Batch 000/156 | Cost: 0.0890
# Epoch: 100/100 | Batch 120/156 | Cost: 0.0412
# Epoch: 100/100 Train Acc.: 97.18% | Validation Acc.: 87.44%
# Time elapsed: 182.24 min
# Total Training Time: 182.24 min

# %%
plt.plot(range(1, NUM_EPOCHS+1), train_loss_lst, label='Training loss')
plt.plot(range(1, NUM_EPOCHS+1), valid_loss_lst, label='Validation loss')
plt.legend(loc='upper right')
plt.ylabel('Cross entropy')
plt.xlabel('Epoch')
plt.show()

# %%
plt.plot(range(1, NUM_EPOCHS+1), train_acc_lst, label='Training accuracy')
plt.plot(range(1, NUM_EPOCHS+1), valid_acc_lst, label='Validation accuracy')
plt.legend(loc='upper left')
plt.ylabel('Cross entropy')
plt.xlabel('Epoch')
plt.show()

# %% [markdown]
# ## Evaluation

# %%
model.eval()
with torch.set_grad_enabled(False): # save memory during inference
    test_acc, test_loss = compute_accuracy_and_loss(model, test_loader, DEVICE)
    print(f'Test accuracy: {test_acc:.2f}%')
# Out:
# Test accuracy: 88.20%

# %%
class UnNormalize(object):
    def __init__(self, mean, std):
        self.mean = mean
        self.std = std

    def __call__(self, tensor):
        """
        Args:
            tensor (Tensor): Tensor image of size (C, H, W) to be normalized.
        Returns:
            Tensor: Normalized image.
        """
        for t, m, s in zip(tensor, self.mean, self.std):
            t.mul_(s).add_(m)
            # The normalize code -> t.sub_(m).div_(s)
        return tensor
    
    
unorm = UnNormalize(mean=train_mean, std=train_std)

# %%
test_loader = DataLoader(dataset=train_dataset, 
                         batch_size=BATCH_SIZE, 
                         shuffle=True)

for features, targets in test_loader:
    break
    

_, predictions = model.forward(features[:8].to(DEVICE))
predictions = torch.argmax(predictions, dim=1)

d = {0: 'cat',
     1: 'dog'}
    
fig, ax = plt.subplots(1, 8, figsize=(20, 10))
for i in range(8):
    img = unorm(features[i])
    ax[i].imshow(np.transpose(img, (1, 2, 0)))
    ax[i].set_xlabel(d[predictions[i].item()])

plt.show()
